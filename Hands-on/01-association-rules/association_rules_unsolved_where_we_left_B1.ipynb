# %% [markdown]
# <a href="https://colab.research.google.com/github/mingshu0922/A09-Consumer-Behaviour-And-Booking-Trends-Of-British-Airways-/blob/main/Hands-on/01-association-rules/association_rules_unsolved_where_we_left_B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Course: BA820 - Unsupervised and Unstructured ML**
#
# **Notebook created by: Mohannad Elhamod**

# %% [markdown]
# #Analyzing Trends at a Grocery Store.
#
# In this notebook, using `mlxtend`, we will analyze the transactions at a grocery store and extract some customer behavior that is of interest to us.

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder

# %% [markdown]
# ## Load the data

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/elhamod/BA820/main/Hands-on/01-association-rules/Kaggle_GroceryStoreDataSet_modified.csv"

df = pd.read_csv(url, header=None)
# In case there are too many rows to load, you can use this parameter:  nrows = 100)

df.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                0
# 0             MILK,BREAD,BISCUIT
# 1  BREAD,MILK,BISCUIT,CORNFLAKES
# 2            BREAD,TEA,BOURNVITA
# 3           JAM,MAGGI,BREAD,MILK
# 4            BREAD,TEA,BOURNVITA

# %%
df.iloc[0,0].split(",")
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['MILK', 'BREAD', 'BISCUIT']

# %% [markdown]
# ## EDA (Exploratory Data Analysis) and Preprocessing

# %% [markdown]
# Convert the text in the table to a list of items

# %%
df[0]
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0                     MILK,BREAD,BISCUIT
# 1          BREAD,MILK,BISCUIT,CORNFLAKES
# 2                    BREAD,TEA,BOURNVITA
# 3                   JAM,MAGGI,BREAD,MILK
# 4                    BREAD,TEA,BOURNVITA
# 5                      MAGGI,TEA,BISCUIT
# 6                   MAGGI,TEA,CORNFLAKES
# 7                MAGGI,BREAD,TEA,BISCUIT
# 8                    JAM,MAGGI,BREAD,TEA
# 9                            ,BREAD,MILK
# 10          CAFE,COKE,BISCUIT,CORNFLAKES
# 11    COFFEE,COCACOLA,BISCUIT,CORNFLAKES
# 12                COFFEE,SUGER,BOURNVITA
# 13                       BREAD,CAFE,COKE
# 14                   BREAD,SUGER,BISCUIT
# 15               COFFEE,SUGER,CORNFLAKES
# 16                 BREAD,SUGER,BOURNVITA
# 17                      BREAD,CAFE,SUGER
# 18                      BREAD,CAFE,SUGER
# 19            TEA,MILK,COFFEE,CORNFLAKES
# Name: 0, dtype: object

# %%
data = [ itemstring.split(",") for itemstring in df[0]]
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [['MILK', 'BREAD', 'BISCUIT'],
#  ['BREAD', 'MILK', 'BISCUIT', 'CORNFLAKES'],
#  ['BREAD', 'TEA', 'BOURNVITA'],
#  ['JAM', 'MAGGI', 'BREAD', 'MILK'],
#  ['BREAD', 'TEA', 'BOURNVITA'],
#  ['MAGGI', 'TEA', 'BISCUIT'],
#  ['MAGGI', 'TEA', 'CORNFLAKES'],
#  ['MAGGI', 'BREAD', 'TEA', 'BISCUIT'],
#  ['JAM', 'MAGGI', 'BREAD', 'TEA'],
#  ['', 'BREAD', 'MILK'],
#  ['CAFE', 'COKE', 'BISCUIT', 'CORNFLAKES'],
#  ['COFFEE', 'COCACOLA', 'BISCUIT', 'CORNFLAKES'],
#  ['COFFEE', 'SUGER', 'BOURNVITA'],
#  ['BREAD', 'CAFE', 'COKE'],
#  ['BREAD', 'SUGER', 'BISCUIT'],
#  ['COFFEE', 'SUGER', 'CORNFLAKES'],
#  ['BREAD', 'SUGER', 'BOURNVITA'],
#  ['BREAD', 'CAFE', 'SUGER'],
#  ['BREAD', 'CAFE', 'SUGER'],
#  ['TEA', 'MILK', 'COFFEE', 'CORNFLAKES']]

# %% [markdown]
# Out of curiousity, what are the unique values?

# %%
all_items = []
for lst in data:
  all_items = all_items + lst
all_items = set(all_items)
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
all_items
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'',
#  'BISCUIT',
#  'BOURNVITA',
#  'BREAD',
#  'CAFE',
#  'COCACOLA',
#  'COFFEE',
#  'COKE',
#  'CORNFLAKES',
#  'JAM',
#  'MAGGI',
#  'MILK',
#  'SUGER',
#  'TEA'}

# %% [markdown]
# Seems we have a couple of things to attend to:
#
# 1.
#
# 2.
#
# 3.
#
# Let's clean up the data.

# %%
for indx, lst in enumerate(data):
  # Remove empty strings:
  lst = [i for i in lst if i]

  # Replace CAFE with COFFEE
  lst = ['COFFEE' if i == 'CAFE' else i for i in lst]

  # Replace COCACOLA with COKE
  lst = ['COKE' if i == 'COCACOLA' else i for i in lst]


  # Update data
  data[indx] = lst

data
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [['MILK', 'BREAD', 'BISCUIT'],
#  ['BREAD', 'MILK', 'BISCUIT', 'CORNFLAKES'],
#  ['BREAD', 'TEA', 'BOURNVITA'],
#  ['JAM', 'MAGGI', 'BREAD', 'MILK'],
#  ['BREAD', 'TEA', 'BOURNVITA'],
#  ['MAGGI', 'TEA', 'BISCUIT'],
#  ['MAGGI', 'TEA', 'CORNFLAKES'],
#  ['MAGGI', 'BREAD', 'TEA', 'BISCUIT'],
#  ['JAM', 'MAGGI', 'BREAD', 'TEA'],
#  ['BREAD', 'MILK'],
#  ['COFFEE', 'COKE', 'BISCUIT', 'CORNFLAKES'],
#  ['COFFEE', 'COKE', 'BISCUIT', 'CORNFLAKES'],
#  ['COFFEE', 'SUGER', 'BOURNVITA'],
#  ['BREAD', 'COFFEE', 'COKE'],
#  ['BREAD', 'SUGER', 'BISCUIT'],
#  ['COFFEE', 'SUGER', 'CORNFLAKES'],
#  ['BREAD', 'SUGER', 'BOURNVITA'],
#  ['BREAD', 'COFFEE', 'SUGER'],
#  ['BREAD', 'COFFEE', 'SUGER'],
#  ['TEA', 'MILK', 'COFFEE', 'CORNFLAKES']]

# %% [markdown]
# ## Market Basket Analysis

# %% [markdown]
# We now have the data in a basket format. We need to convert it into a encoded format.

# %%
# Transform data
te = TransactionEncoder()
transactions =te.fit(data).transform(data)

# Create a dataframe from the data
df_encoded = pd.DataFrame(transactions, columns=te.columns_)
df_encoded
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     BISCUIT  BOURNVITA  BREAD  COFFEE   COKE  CORNFLAKES    JAM  MAGGI   MILK  \
# 0      True      False   True   False  False       False  False  False   True
# 1      True      False   True   False  False        True  False  False   True
# 2     False       True   True   False  False       False  False  False  False
# 3     False      False   True   False  False       False   True   True   True
# 4     False       True   True   False  False       False  False  False  False
# 5      True      False  False   False  False       False  False   True  False
# 6     False      False  False   False  False        True  False   True  False
# 7      True      False   True   False  False       False  False   True  False
# 8     False      False   True   False  False       False   True   True  False
# 9     False      False   True   False  False       False  False  False   True
# 10     True      False  False    True   True        True  False  False  False
# 11     True      False  False    True   True        True  False  False  False
# 12    False       True  False    True  False       False  False  False  False
# 13    False      False   True    True   True       False  False  False  False
# 14     True      False   True   False  False       False  False  False  False
# 15    False      False  False    True  False        True  False  False  False
# 16    False       True   True   False  False       False  False  False  False
# 17    False      False   True    True  False       False  False  False  False
# 18    False      False   True    True  False       False  False  False  False
# 19    False      False  False    True  False        True  False  False   True
#
#     SUGER    TEA
# 0   False  False
# 1   False  False
# 2   False   True
# 3   False  False
# 4   False   True
# 5   False   True
# 6   False   True
# 7   False   True
# 8   False   True
# 9   False  False
# 10  False  False
# 11  False  False
# 12   True  False
# 13  False  False
# 14   True  False
# 15   True  False
# 16   True  False
# 17   True  False
# 18   True  False
# 19  False   True

# %% [markdown]
# Let's find the most frequent itemsets.

# %%
frequent_itemsets = apriori(df_encoded, min_support=0.1, use_colnames=True)
frequent_itemsets
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     support                             itemsets
# 0      0.35                            (BISCUIT)
# 1      0.20                          (BOURNVITA)
# 2      0.65                              (BREAD)
# 3      0.40                             (COFFEE)
# 4      0.15                               (COKE)
# 5      0.30                         (CORNFLAKES)
# 6      0.10                                (JAM)
# 7      0.25                              (MAGGI)
# 8      0.25                               (MILK)
# 9      0.30                              (SUGER)
# 10     0.35                                (TEA)
# 11     0.20                     (BREAD, BISCUIT)
# 12     0.10                    (COFFEE, BISCUIT)
# 13     0.10                      (COKE, BISCUIT)
# 14     0.15                (CORNFLAKES, BISCUIT)
# 15     0.10                     (MAGGI, BISCUIT)
# 16     0.10                      (MILK, BISCUIT)
# 17     0.10                       (TEA, BISCUIT)
# 18     0.15                   (BREAD, BOURNVITA)
# 19     0.10                   (SUGER, BOURNVITA)
# 20     0.10                     (BOURNVITA, TEA)
# 21     0.15                      (BREAD, COFFEE)
# 22     0.10                         (BREAD, JAM)
# 23     0.15                       (BREAD, MAGGI)
# 24     0.20                        (BREAD, MILK)
# 25     0.20                       (SUGER, BREAD)
# 26     0.20                         (BREAD, TEA)
# 27     0.15                       (COKE, COFFEE)
# 28     0.20                 (COFFEE, CORNFLAKES)
# 29     0.20                      (SUGER, COFFEE)
# 30     0.10                   (COKE, CORNFLAKES)
# 31     0.10                   (MILK, CORNFLAKES)
# 32     0.10                    (TEA, CORNFLAKES)
# 33     0.10                         (JAM, MAGGI)
# 34     0.20                         (TEA, MAGGI)
# 35     0.10               (BREAD, MILK, BISCUIT)
# 36     0.10              (COKE, COFFEE, BISCUIT)
# 37     0.10        (COFFEE, CORNFLAKES, BISCUIT)
# 38     0.10          (COKE, CORNFLAKES, BISCUIT)
# 39     0.10                (MAGGI, TEA, BISCUIT)
# 40     0.10              (BREAD, BOURNVITA, TEA)
# 41     0.10               (SUGER, COFFEE, BREAD)
# 42     0.10                  (BREAD, MAGGI, JAM)
# 43     0.10                  (BREAD, TEA, MAGGI)
# 44     0.10           (COKE, COFFEE, CORNFLAKES)
# 45     0.10  (COKE, COFFEE, CORNFLAKES, BISCUIT)

# %% [markdown]
# Let's find the rules of interest.

# %%
rules = association_rules(frequent_itemsets, )
rules
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                       antecedents           consequents  antecedent support  \
# 0                           (JAM)               (BREAD)                0.10
# 1                          (MILK)               (BREAD)                0.25
# 2                          (COKE)              (COFFEE)                0.15
# 3                           (JAM)               (MAGGI)                0.10
# 4                         (MAGGI)                 (TEA)                0.25
# 5                 (MILK, BISCUIT)               (BREAD)                0.10
# 6                 (COKE, BISCUIT)              (COFFEE)                0.10
# 7               (COFFEE, BISCUIT)                (COKE)                0.10
# 8               (COFFEE, BISCUIT)          (CORNFLAKES)                0.10
# 9              (COKE, CORNFLAKES)             (BISCUIT)                0.10
# 10                (COKE, BISCUIT)          (CORNFLAKES)                0.10
# 11               (BISCUIT, MAGGI)                 (TEA)                0.10
# 12                 (TEA, BISCUIT)               (MAGGI)                0.10
# 13               (BOURNVITA, TEA)               (BREAD)                0.10
# 14                   (BREAD, JAM)               (MAGGI)                0.10
# 15                   (JAM, MAGGI)               (BREAD)                0.10
# 16                          (JAM)        (BREAD, MAGGI)                0.10
# 17             (COKE, CORNFLAKES)              (COFFEE)                0.10
# 18     (COKE, COFFEE, CORNFLAKES)             (BISCUIT)                0.10
# 19        (COKE, COFFEE, BISCUIT)          (CORNFLAKES)                0.10
# 20    (COKE, BISCUIT, CORNFLAKES)              (COFFEE)                0.10
# 21  (COFFEE, BISCUIT, CORNFLAKES)                (COKE)                0.10
# 22             (COKE, CORNFLAKES)     (COFFEE, BISCUIT)                0.10
# 23                (COKE, BISCUIT)  (COFFEE, CORNFLAKES)                0.10
# 24              (COFFEE, BISCUIT)    (COKE, CORNFLAKES)                0.10
#
#     consequent support  support  confidence       lift  representativity  \
# 0                 0.65     0.10         1.0   1.538462               1.0
# 1                 0.65     0.20         0.8   1.230769               1.0
# 2                 0.40     0.15         1.0   2.500000               1.0
# 3                 0.25     0.10         1.0   4.000000               1.0
# 4                 0.35     0.20         0.8   2.285714               1.0
# 5                 0.65     0.10         1.0   1.538462               1.0
# 6                 0.40     0.10         1.0   2.500000               1.0
# 7                 0.15     0.10         1.0   6.666667               1.0
# 8                 0.30     0.10         1.0   3.333333               1.0
# 9                 0.35     0.10         1.0   2.857143               1.0
# 10                0.30     0.10         1.0   3.333333               1.0
# 11                0.35     0.10         1.0   2.857143               1.0
# 12                0.25     0.10         1.0   4.000000               1.0
# 13                0.65     0.10         1.0   1.538462               1.0
# 14                0.25     0.10         1.0   4.000000               1.0
# 15                0.65     0.10         1.0   1.538462               1.0
# 16                0.15     0.10         1.0   6.666667               1.0
# 17                0.40     0.10         1.0   2.500000               1.0
# 18                0.35     0.10         1.0   2.857143               1.0
# 19                0.30     0.10         1.0   3.333333               1.0
# 20                0.40     0.10         1.0   2.500000               1.0
# 21                0.15     0.10         1.0   6.666667               1.0
# 22                0.10     0.10         1.0  10.000000               1.0
# 23                0.20     0.10         1.0   5.000000               1.0
# 24                0.10     0.10         1.0  10.000000               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0     0.0350         inf       0.388889  0.153846   1.000000    0.576923
# 1     0.0375        1.75       0.250000  0.285714   0.428571    0.553846
# 2     0.0900         inf       0.705882  0.375000   1.000000    0.687500
# 3     0.0750         inf       0.833333  0.400000   1.000000    0.700000
# 4     0.1125        3.25       0.750000  0.500000   0.692308    0.685714
# 5     0.0350         inf       0.388889  0.153846   1.000000    0.576923
# 6     0.0600         inf       0.666667  0.250000   1.000000    0.625000
# 7     0.0850         inf       0.944444  0.666667   1.000000    0.833333
# 8     0.0700         inf       0.777778  0.333333   1.000000    0.666667
# 9     0.0650         inf       0.722222  0.285714   1.000000    0.642857
# 10    0.0700         inf       0.777778  0.333333   1.000000    0.666667
# 11    0.0650         inf       0.722222  0.285714   1.000000    0.642857
# 12    0.0750         inf       0.833333  0.400000   1.000000    0.700000
# 13    0.0350         inf       0.388889  0.153846   1.000000    0.576923
# 14    0.0750         inf       0.833333  0.400000   1.000000    0.700000
# 15    0.0350         inf       0.388889  0.153846   1.000000    0.576923
# 16    0.0850         inf       0.944444  0.666667   1.000000    0.833333
# 17    0.0600         inf       0.666667  0.250000   1.000000    0.625000
# 18    0.0650         inf       0.722222  0.285714   1.000000    0.642857
# 19    0.0700         inf       0.777778  0.333333   1.000000    0.666667
# 20    0.0600         inf       0.666667  0.250000   1.000000    0.625000
# 21    0.0850         inf       0.944444  0.666667   1.000000    0.833333
# 22    0.0900         inf       1.000000  1.000000   1.000000    1.000000
# 23    0.0800         inf       0.888889  0.500000   1.000000    0.750000
# 24    0.0900         inf       1.000000  1.000000   1.000000    1.000000

# %% [markdown]
# Let's filter the rules further.

# %%
rules_filtered = rules[rules['confidence'] > 0.5]
rules_filtered
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                       antecedents           consequents  antecedent support  \
# 0                           (JAM)               (BREAD)                0.10
# 1                          (MILK)               (BREAD)                0.25
# 2                          (COKE)              (COFFEE)                0.15
# 3                           (JAM)               (MAGGI)                0.10
# 4                         (MAGGI)                 (TEA)                0.25
# 5                 (MILK, BISCUIT)               (BREAD)                0.10
# 6                 (COKE, BISCUIT)              (COFFEE)                0.10
# 7               (COFFEE, BISCUIT)                (COKE)                0.10
# 8               (COFFEE, BISCUIT)          (CORNFLAKES)                0.10
# 9              (COKE, CORNFLAKES)             (BISCUIT)                0.10
# 10                (COKE, BISCUIT)          (CORNFLAKES)                0.10
# 11               (BISCUIT, MAGGI)                 (TEA)                0.10
# 12                 (TEA, BISCUIT)               (MAGGI)                0.10
# 13               (BOURNVITA, TEA)               (BREAD)                0.10
# 14                   (BREAD, JAM)               (MAGGI)                0.10
# 15                   (JAM, MAGGI)               (BREAD)                0.10
# 16                          (JAM)        (BREAD, MAGGI)                0.10
# 17             (COKE, CORNFLAKES)              (COFFEE)                0.10
# 18     (COKE, COFFEE, CORNFLAKES)             (BISCUIT)                0.10
# 19        (COKE, COFFEE, BISCUIT)          (CORNFLAKES)                0.10
# 20    (COKE, BISCUIT, CORNFLAKES)              (COFFEE)                0.10
# 21  (COFFEE, BISCUIT, CORNFLAKES)                (COKE)                0.10
# 22             (COKE, CORNFLAKES)     (COFFEE, BISCUIT)                0.10
# 23                (COKE, BISCUIT)  (COFFEE, CORNFLAKES)                0.10
# 24              (COFFEE, BISCUIT)    (COKE, CORNFLAKES)                0.10
#
#     consequent support  support  confidence       lift  representativity  \
# 0                 0.65     0.10         1.0   1.538462               1.0
# 1                 0.65     0.20         0.8   1.230769               1.0
# 2                 0.40     0.15         1.0   2.500000               1.0
# 3                 0.25     0.10         1.0   4.000000               1.0
# 4                 0.35     0.20         0.8   2.285714               1.0
# 5                 0.65     0.10         1.0   1.538462               1.0
# 6                 0.40     0.10         1.0   2.500000               1.0
# 7                 0.15     0.10         1.0   6.666667               1.0
# 8                 0.30     0.10         1.0   3.333333               1.0
# 9                 0.35     0.10         1.0   2.857143               1.0
# 10                0.30     0.10         1.0   3.333333               1.0
# 11                0.35     0.10         1.0   2.857143               1.0
# 12                0.25     0.10         1.0   4.000000               1.0
# 13                0.65     0.10         1.0   1.538462               1.0
# 14                0.25     0.10         1.0   4.000000               1.0
# 15                0.65     0.10         1.0   1.538462               1.0
# 16                0.15     0.10         1.0   6.666667               1.0
# 17                0.40     0.10         1.0   2.500000               1.0
# 18                0.35     0.10         1.0   2.857143               1.0
# 19                0.30     0.10         1.0   3.333333               1.0
# 20                0.40     0.10         1.0   2.500000               1.0
# 21                0.15     0.10         1.0   6.666667               1.0
# 22                0.10     0.10         1.0  10.000000               1.0
# 23                0.20     0.10         1.0   5.000000               1.0
# 24                0.10     0.10         1.0  10.000000               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0     0.0350         inf       0.388889  0.153846   1.000000    0.576923
# 1     0.0375        1.75       0.250000  0.285714   0.428571    0.553846
# 2     0.0900         inf       0.705882  0.375000   1.000000    0.687500
# 3     0.0750         inf       0.833333  0.400000   1.000000    0.700000
# 4     0.1125        3.25       0.750000  0.500000   0.692308    0.685714
# 5     0.0350         inf       0.388889  0.153846   1.000000    0.576923
# 6     0.0600         inf       0.666667  0.250000   1.000000    0.625000
# 7     0.0850         inf       0.944444  0.666667   1.000000    0.833333
# 8     0.0700         inf       0.777778  0.333333   1.000000    0.666667
# 9     0.0650         inf       0.722222  0.285714   1.000000    0.642857
# 10    0.0700         inf       0.777778  0.333333   1.000000    0.666667
# 11    0.0650         inf       0.722222  0.285714   1.000000    0.642857
# 12    0.0750         inf       0.833333  0.400000   1.000000    0.700000
# 13    0.0350         inf       0.388889  0.153846   1.000000    0.576923
# 14    0.0750         inf       0.833333  0.400000   1.000000    0.700000
# 15    0.0350         inf       0.388889  0.153846   1.000000    0.576923
# 16    0.0850         inf       0.944444  0.666667   1.000000    0.833333
# 17    0.0600         inf       0.666667  0.250000   1.000000    0.625000
# 18    0.0650         inf       0.722222  0.285714   1.000000    0.642857
# 19    0.0700         inf       0.777778  0.333333   1.000000    0.666667
# 20    0.0600         inf       0.666667  0.250000   1.000000    0.625000
# 21    0.0850         inf       0.944444  0.666667   1.000000    0.833333
# 22    0.0900         inf       1.000000  1.000000   1.000000    1.000000
# 23    0.0800         inf       0.888889  0.500000   1.000000    0.750000
# 24    0.0900         inf       1.000000  1.000000   1.000000    1.000000

# %% [markdown]
# ## Let's do some analysis through visualizations.

# %% [markdown]
# ###Visually identifying the rules that apply most commonly to my customers.

# %% [markdown]
# First, some necessary string manipulation to beautify the visualization labels.

# %%
rules_filtered['antecedents'] = rules_filtered['antecedents'].apply(lambda a: ','.join(list(a)))
rules_filtered['consequents'] = rules_filtered['consequents'].apply(lambda a: ','.join(list(a)))

# %% [markdown]
# Then, I want to see the support for each antecedent-consequent pair.

# %%
support_table = rules_filtered.pivot(   )

import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(18, 12))  # Adjust the width and height
sns.heatmap(support_table, annot=True, linewidths=0.5, linecolor='gray', cmap='coolwarm')
plt.show()

# %% [markdown]
# ## Questions worth investigating

# %% [markdown]
# *   Get some stats on the dataset, such as the average number of items per transaction and the 10 most frequent transactions.
# *   Filter the rules down to those that are useful for promoting items to customers once they have 3 items in their cart.
# *   If you have an excess of tea that is expiring soon in your stock and you want to sell it out quickly, which customer base would you promote it to?
# *   How does the computational complexity (i.e., how long it takes the algorithm to run) change as we change the number of transactions and/or our filtering criteria? One could use the `%%timeit`.
